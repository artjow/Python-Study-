# %% [markdown]
# <a href="https://colab.research.google.com/github/chohyungrae/Python-Study-/blob/master/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set(style='darkgrid')#바탕색 지정
sns.relplot(x='total_bill', y='tip', data=tips)

# %%
#hue 색상
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker')

# %%
#사이즈
sns.relplot(x='total_bill', y='tip', data=tips, hue='size')

# %%
#색상
sns.relplot(x='total_bill', y='tip', data=tips, hue='size', palette='GnBua')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/seaborn/palettes.py in color_palette(palette, n_colors, desat, as_cmap)
#     205                 # Perhaps a named matplotlib colormap?
# --> 206                 palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     207             except ValueError:
#
# /usr/local/lib/python3.6/dist-packages/seaborn/palettes.py in mpl_palette(name, n_colors, as_cmap)
#     442     else:
# --> 443         cmap = mpl.cm.get_cmap(name)
#     444
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cm.py in get_cmap(name, lut)
#     133         return name
# --> 134     cbook._check_in_list(sorted(cmap_d), name=name)
#     135     if lut is None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in _check_in_list(_values, **kwargs)
# ...

# %%
#색상
sns.relplot(x='total_bill', y='tip', data=tips, hue='size', palette='GnBu')

# %%
#사이즈
#색상
sns.relplot(x='total_bill', y='tip', data=tips, size='size')

# %%
#라인그리기

# %%
df=pd.DataFrame(dict(time=np.arange(500), value=np.random.randn(500). cumsum()))#cumsum누적합
df
# Out:
#      time      value
# 0       0   2.006304
# 1       1   2.052825
# 2       2   1.730678
# 3       3   3.657173
# 4       4   4.338252
# ..    ...        ...
# 495   495  19.652416
# 496   496  20.153475
# 497   497  20.996798
# 498   498  18.869643
# 499   499  17.931222
#
# [500 rows x 2 columns]

# %%
sns.relplot(x='time', y='value', data=df, kind='line')

# %%
fmri=sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x='timepoint', y='signal', kind='line', data=fmri, ci=None)#ci는 선 범위 조절

# %%
sns.relplot(x='timepoint', y='signal', kind='line', data=fmri)

# %%
fmri=sns.load_dataset('fmri')
fmri
sns.relplot(x='timepoint', y='signal', kind='line', data=fmri, ci='sd')

# %%
fmri=sns.load_dataset('fmri')
fmri
sns.relplot(x='timepoint', y='signal', kind='line', data=fmri, hue='region', style='event')

# %%
#cat plot

# %%
sns.catplot(x='day', y='total_bill', data=tips )

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='swarm' )#swarm은 겹치치않는것

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='box')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='violin')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='boxen')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='bar')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='point')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='violin', hue='sex')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='violin', hue='sex', inner='stick', split='True')

# %%
tips.shape#데이터의 개수
# Out:
# (244, 7)

# %%
#titanic 데이터

# %%
titanic=sns.load_dataset('titanic')
sns.catplot(x='sex', y='survived', hue='class', kind='bar', data=titanic)

# %% [markdown]
# ### **Seaborn 그래프 합치기 Jointploit**

# %%
import pandas as pd
import numpy as np
import seaborn as sns # seaborn을 불러온다

# %%
df = pd.DataFrame(np.random.randn(500,2), columns=['1', '2'])
df
# Out:
#             1         2
# 0   -0.176434  0.016879
# 1    1.089811 -1.253451
# 2   -1.063220  0.500152
# 3   -0.102113 -1.060712
# 4    1.298324  1.408203
# ..        ...       ...
# 495  1.312879 -1.604353
# 496 -0.666516  0.377703
# 497 -1.289081 -0.448315
# 498  0.761105  0.242409
# 499 -1.131409 -1.550446
#
# [500 rows x 2 columns]

# %%
sns.relplot(x='1', y='2', data=df)

# %%
'''
jointplot이 있는 seaborn사이트 링크
https://seaborn.pydata.org/generated/seaborn.jointplot.html#seaborn.jointplot
'''
sns.jointplot(x='1', y='2', data=df)

# %%
sns.jointplot(x='1', y='2', data=df, kind='hex')

# %%
sns.jointplot(x='1', y='2', data=df, kind='kde')

# %%
sns.jointplot(x='1', y='2', data=df, kind='resid')

# %%
sns.jointplot(x='1', y='2', data=df, kind='reg')
