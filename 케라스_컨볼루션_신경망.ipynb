# %% [markdown]
# <a href="https://colab.research.google.com/github/chohyungrae/Python-Study-/blob/master/%EC%BC%80%EB%9D%BC%EC%8A%A4_%EC%BB%A8%EB%B3%BC%EB%A3%A8%EC%85%98_%EC%8B%A0%EA%B2%BD%EB%A7%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D

import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

import numpy as np
from sklearn.datasets import load_sample_image

# %%
china = load_sample_image('china.jpg') / 255
print(china.dtype)
print(china.shape)
# Out:
# float64
# (427, 640, 3)

# %%
plt.imshow(china)
plt.show()

# %%
flower = load_sample_image('flower.jpg') / 255
print(flower.dtype)
print(flower.shape)
# Out:
# float64
# (427, 640, 3)

# %%
plt.imshow(flower)
plt.show()

# %%
images = np.array([china, flower]) #이미지를 묶는다
batch_size, height, width, channels = images.shape
print(images.shape)
# Out:
# (2, 427, 640, 3)

# %%
filters = np.zeros(shape=(7,7,channels,2), dtype=np.float32)
filters[:,3,:,0]=1
filters[3,:,:,1]=1

print(filters.shape)
# Out:
# (7, 7, 3, 2)

# %%
outputs = tf.nn.conv2d(images, filters, strides=1, padding="SAME")
print(outputs.shape)
plt.imshow(outputs[0,:,:,1], cmap='gray')
plt.show()
# Out:
# (2, 427, 640, 2)

# %%
plt.imshow(outputs[0,:,:,0], cmap='gray')
plt.show()

# %%
conv = Conv2D(filters=32, kernel_size=3, strides=1,
              padding="same", activation='relu')
